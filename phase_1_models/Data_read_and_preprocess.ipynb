# %%
from helper import get_req_handler, initBoto3Session, get_s3_objs
from dotenv import load_dotenv
import boto3
import os
from io import StringIO

import pandas as pd
import numpy as np

# %% [markdown]
# # Camera to Location Map

# %%
cam_to_loc = pd.read_csv("camera_station_mapping.csv")
cam_to_loc = cam_to_loc.rename(columns = {"rainfall" : "rainfall_station_id", 
                                         "not_rainfall" : "non_rainfall_station_id", 
                                         "region" : "2hr_forecast_area"})
cam_to_loc.head()
# Out:
#    cam_id non_rainfall_station_id rainfall_station_id 2hr_forecast_area  \
# 0    1001                    S108                S119           Kallang
# 1    1002                    S108                S215           Geylang
# 2    1003                    S108                S123           Kallang
# 3    1004                    S108                S215           Kallang
# 4    1005                    S107                S221        Paya Lebar
#
#    compass
# 0    south
# 1     east
# 2  central
# 3  central
# 4     east

# %% [markdown]
# # Set Up

# %%
load_dotenv()

aws_access_key_id=os.environ["AWS_ACCESS_KEY_ID"]
aws_secret_access_key=os.environ["AWS_SECRET_ACCESS_KEY"]

client = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)

bucket_name = os.environ["BUCKET_NAME"]
data_dir = os.environ["DATA_DIR"]

# %%
def get_csv(file_name):
    csv_obj = client.get_object(Bucket=bucket_name, Key= data_dir + file_name)
    body = csv_obj['Body']
    csv_string = body.read().decode('utf-8')
    df = pd.read_csv(StringIO(csv_string))
    df = df.drop("Unnamed: 0", axis = 1)
    return df

# %% [markdown]
# # Read Files
#
# IMPORTANT: Note all data will be consistent (sometime the stations wont appear)
# Time stamps are also different - shimar looking into it

# %%
rainfall_realtime = get_csv("rainfall-realtime.csv" )
rainfall_realtime.head()
# Out:
#            timestamp station_id         station_loc            station_name  \
# 0  2022-03-31T222500        S77  (1.2937, 103.8125)          Alexandra Road
# 1  2022-03-31T222500       S109  (1.3764, 103.8492)     Ang Mo Kio Avenue 5
# 2  2022-03-31T222500        S90  (1.3191, 103.8191)        Bukit Timah Road
# 3  2022-03-31T222500       S114      (1.38, 103.73)  Choa Chu Kang Avenue 4
# 4  2022-03-31T222500        S50  (1.3337, 103.7768)           Clementi Road
#
#    rainfall_realtime     call_timestamp
# 0                0.0  2022-03-31T223549
# 1                0.0  2022-03-31T223549
# 2                0.0  2022-03-31T223549
# 3                0.0  2022-03-31T223549
# 4                0.0  2022-03-31T223549

# %%
non_rainfall_realtime = get_csv("non-rainfall-realtime.csv" )
non_rainfall_realtime.head()
# Out:
#            timestamp station_id           station_loc  \
# 0  2022-03-31T223000       S107    (1.3135, 103.9625)
# 1  2022-03-31T223000       S108    (1.2799, 103.8703)
# 2  2022-03-31T223000        S44  (1.34583, 103.68166)
# 3  2022-03-31T223000       S106    (1.4168, 103.9673)
# 4  2022-03-31T223000        S24    (1.3678, 103.9826)
#
#               station_name  wind_speed_realtime  wind_dir_realtime  \
# 0       East Coast Parkway                  2.7                251
# 1     Marina Gardens Drive                  1.6                251
# 2           Nanyang Avenue                  1.1                230
# 3               Pulau Ubin                  0.9                266
# 4  Upper Changi Road North                  1.8                329
#
#    RH%_realtime  air_temp_realtime     call_timestamp
# 0          78.2               28.6  2022-03-31T223549
# 1          93.9               27.6  2022-03-31T223549
# 2          82.7               27.4  2022-03-31T223549
# 3          96.5               25.7  2022-03-31T223549
# 4          84.7               27.5  2022-03-31T223549

# %%
forecast_4d = get_csv("forecast-4DAY.csv")
forecast_4d.head()
# Out:
#            4day_date               4day_forecast  4day_temperature_low  \
# 0  2022-04-01T000000  Afternoon thundery showers                    24
# 1  2022-04-02T000000  Afternoon thundery showers                    24
# 2  2022-04-03T000000  Afternoon thundery showers                    24
# 3  2022-04-04T000000  Afternoon thundery showers                    24
# 4  2022-04-01T000000  Afternoon thundery showers                    24
#
#    4day_temperature_high  4day_relative_humidity_low  \
# 0                     34                          65
# 1                     34                          65
# 2                     34                          65
# 3                     34                          65
# 4                     34                          65
#
#    4day_relative_humidity_high  4day_wind_speed_low  4day_wind_speed_high  \
# 0                           95                    5                    15
# 1                           95                    5                    15
# 2                           90                    5                    15
# 3                           90                    5                    15
# 4                           95                    5                    15
#
#   4day_wind_direction 4day_update_timestamp     call_timestamp
# 0                  NW     2022-03-31T173213  2022-03-31T223549
# 1                  NW     2022-03-31T173213  2022-03-31T223549
# 2                   W     2022-03-31T173213  2022-03-31T223549
# 3                   W     2022-03-31T173213  2022-03-31T223549
# 4                  NW     2022-03-31T173213  2022-03-31T223627

# %%
forecast_24h = get_csv("forecast-24HR.csv")
forecast_24h.head()
# Out:
#           24hr_start           24hr_end 24hr_general_forecast  \
# 0  2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 1  2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 2  2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 3  2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 4  2022-03-31T180000  2022-04-01T180000      Thundery Showers
#
#    24hr_general_relative_humidity_low  24hr_general_relative_humidity_high  \
# 0                                  60                                   95
# 1                                  60                                   95
# 2                                  60                                   95
# 3                                  60                                   95
# 4                                  60                                   95
#
#    24hr_general_temperature_low  24hr_general_temperature_high  \
# 0                            24                             34
# 1                            24                             34
# 2                            24                             34
# 3                            24                             34
# 4                            24                             34
#
#    24hr_general_wind_speed_low  24hr_general_wind_speed_high  \
# 0                           10                            20
# 1                           10                            20
# 2                           10                            20
# 3                           10                            20
# 4                           10                            20
#
#   24hr_general_wind_direction  ... 24hr_period_3_forecast_south  \
# 0                          NW  ...             Thundery Showers
# 1                          NW  ...             Thundery Showers
# 2                          NW  ...             Thundery Showers
# 3                          NW  ...             Thundery Showers
# 4                          NW  ...             Thundery Showers
#
#   24hr_period_3_forecast_north     call_timestamp 24hr_period_4_start  \
# 0             Thundery Showers  2022-03-31T223549                 NaN
# 1             Thundery Showers  2022-03-31T223627                 NaN
# 2             Thundery Showers  2022-03-31T225031                 NaN
# 3             Thundery Showers  2022-03-31T225533                 NaN
# 4             Thundery Showers  2022-03-31T230035                 NaN
#
#   24hr_period_4_end 24hr_period_4_forecast_west 24hr_period_4_forecast_east  \
# 0               NaN                         NaN                         NaN
# 1               NaN                         NaN                         NaN
# 2               NaN                         NaN                         NaN
# 3               NaN                         NaN                         NaN
# 4               NaN                         NaN                         NaN
#
#   24hr_period_4_forecast_central 24hr_period_4_forecast_south  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   24hr_period_4_forecast_north
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 39 columns]

# %%
forecast_2h = get_csv("forecast-2HR.csv")
forecast_2h.head()
# Out:
#   2hr_forecast_area 2hr_forecast_area_loc 2hr_forecast_value  \
# 0        Ang Mo Kio      (1.375, 103.839)             Cloudy
# 1             Bedok      (1.321, 103.924)             Cloudy
# 2            Bishan   (1.350772, 103.839)             Cloudy
# 3          Boon Lay      (1.304, 103.701)             Cloudy
# 4       Bukit Batok      (1.353, 103.754)             Cloudy
#
#            2hr_start            2hr_end     call_timestamp
# 0  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549
# 1  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549
# 2  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549
# 3  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549
# 4  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549

# %%
bing_data = pd.read_csv("sample_bing.csv").drop("Unnamed: 0", axis = 1)
bing_data.head()
# Out:
#    camera_id  direction trafficCongestion  travelDistance  travelDuration  \
# 0       1704          1             Heavy           0.105               7
# 1       1704          2              Mild           0.127               7
# 2       1704          3             Heavy           0.117               5
# 3       1704          4             Heavy           0.114               5
# 4       1705          1              None           0.214               9
#
#    travelDurationTraffic distanceUnit durationUnit     call_timestamp  \
# 0                     13    Kilometer       Second  2022-04-03T105710
# 1                      8    Kilometer       Second  2022-04-03T105710
# 2                      8    Kilometer       Second  2022-04-03T105710
# 3                      8    Kilometer       Second  2022-04-03T105710
# 4                      9    Kilometer       Second  2022-04-03T105710
#
#                                 cam_loc Lopsided  \
# 0  (1.28569398886979, 103.837524510188)    FALSE
# 1  (1.28569398886979, 103.837524510188)    FALSE
# 2  (1.28569398886979, 103.837524510188)    FALSE
# 3  (1.28569398886979, 103.837524510188)    FALSE
# 4            (1.375925022, 103.8587986)    FALSE
#
#                                   dir_start  \
# 0  (1.2853061926158522, 103.83723720205947)
# 1  (1.2852273564227954, 103.83728977274863)
# 2   (1.2851962997400104, 103.8373901349734)
# 3   (1.285877157699029, 103.83818347446437)
# 4  (1.3752939035761242, 103.85871517155806)
#
#                                  dir_finish
# 0  (1.2859727166962915, 103.83792540017214)
# 1  (1.2859942174701802, 103.83811178716098)
# 2  (1.2859416600225777, 103.83813329335197)
# 3  (1.2851174635435438, 103.83748332846783)
# 4   (1.377181002101763, 103.85832766854271)

# %% [markdown]
# # Processing
#
# So the objective here is to make the dataset into a useable one - ie the whole long row as we would input into a model
# Chances are going to have to process individually.
# The superkey to join all tables will be the timestamp except forecast idk how that will work
#
# ## Realtime Rainfall

# %%
# original view
rainfall_realtime.head()
# Out:
#            timestamp station_id         station_loc            station_name  \
# 0  2022-03-31T222500        S77  (1.2937, 103.8125)          Alexandra Road
# 1  2022-03-31T222500       S109  (1.3764, 103.8492)     Ang Mo Kio Avenue 5
# 2  2022-03-31T222500        S90  (1.3191, 103.8191)        Bukit Timah Road
# 3  2022-03-31T222500       S114      (1.38, 103.73)  Choa Chu Kang Avenue 4
# 4  2022-03-31T222500        S50  (1.3337, 103.7768)           Clementi Road
#
#    rainfall_realtime     call_timestamp
# 0                0.0  2022-03-31T223549
# 1                0.0  2022-03-31T223549
# 2                0.0  2022-03-31T223549
# 3                0.0  2022-03-31T223549
# 4                0.0  2022-03-31T223549

# %%
rainfall_realtime = rainfall_realtime[["call_timestamp", "station_id", "rainfall_realtime"]]
rainfall_realtime = rainfall_realtime.rename(columns = {"station_id" : "rainfall_station_id"})
rainfall_realtime.head()
# Out:
#       call_timestamp rainfall_station_id  rainfall_realtime
# 0  2022-03-31T223549                 S77                0.0
# 1  2022-03-31T223549                S109                0.0
# 2  2022-03-31T223549                 S90                0.0
# 3  2022-03-31T223549                S114                0.0
# 4  2022-03-31T223549                 S50                0.0

# %% [markdown]
# ## Realtime non rainfall

# %%
non_rainfall_realtime.head()
# Out:
#            timestamp station_id           station_loc  \
# 0  2022-03-31T223000       S107    (1.3135, 103.9625)
# 1  2022-03-31T223000       S108    (1.2799, 103.8703)
# 2  2022-03-31T223000        S44  (1.34583, 103.68166)
# 3  2022-03-31T223000       S106    (1.4168, 103.9673)
# 4  2022-03-31T223000        S24    (1.3678, 103.9826)
#
#               station_name  wind_speed_realtime  wind_dir_realtime  \
# 0       East Coast Parkway                  2.7                251
# 1     Marina Gardens Drive                  1.6                251
# 2           Nanyang Avenue                  1.1                230
# 3               Pulau Ubin                  0.9                266
# 4  Upper Changi Road North                  1.8                329
#
#    RH%_realtime  air_temp_realtime     call_timestamp
# 0          78.2               28.6  2022-03-31T223549
# 1          93.9               27.6  2022-03-31T223549
# 2          82.7               27.4  2022-03-31T223549
# 3          96.5               25.7  2022-03-31T223549
# 4          84.7               27.5  2022-03-31T223549

# %%
non_rainfall_realtime = non_rainfall_realtime.rename(columns = {"RH%_realtime" : "humidity_realtime", 
                                                               "station_id" : "non_rainfall_station_id"})

# %%
non_rainfall_realtime = non_rainfall_realtime[["call_timestamp", "non_rainfall_station_id", "wind_speed_realtime", 
                                               "wind_dir_realtime", "humidity_realtime", "air_temp_realtime"]]
non_rainfall_realtime.head()
# Out:
#       call_timestamp non_rainfall_station_id  wind_speed_realtime  \
# 0  2022-03-31T223549                    S107                  2.7
# 1  2022-03-31T223549                    S108                  1.6
# 2  2022-03-31T223549                     S44                  1.1
# 3  2022-03-31T223549                    S106                  0.9
# 4  2022-03-31T223549                     S24                  1.8
#
#    wind_dir_realtime  humidity_realtime  air_temp_realtime
# 0                251               78.2               28.6
# 1                251               93.9               27.6
# 2                230               82.7               27.4
# 3                266               96.5               25.7
# 4                329               84.7               27.5

# %% [markdown]
# ## 4 Day Forecast

# %%
forecast_4d["4day_date"] = pd.to_datetime(forecast_4d["4day_date"])
forecast_4d["grp_row_num"] = forecast_4d.sort_values("4day_date").groupby(["4day_update_timestamp", "call_timestamp"])["4day_date"].cumcount()+1
forecast_4d["grp_row_num"] = forecast_4d.grp_row_num.apply(lambda x : str(x))
forecast_4d = forecast_4d.drop("4day_date", axis = 1)
forecast_4d = forecast_4d.pivot(index = "call_timestamp", columns = "grp_row_num")
forecast_4d.columns = ['_'.join(col) for col in forecast_4d.columns]
forecast_4d = forecast_4d.drop(["4day_update_timestamp_1", "4day_update_timestamp_2", 
                  "4day_update_timestamp_3", "4day_update_timestamp_4"], axis = 1)
forecast_4d = forecast_4d.reset_index()
forecast_4d.head()
# Out:
#       call_timestamp             4day_forecast_1             4day_forecast_2  \
# 0  2022-03-31T182424  Afternoon thundery showers  Afternoon thundery showers
# 1  2022-03-31T182939  Afternoon thundery showers  Afternoon thundery showers
# 2  2022-03-31T183526  Afternoon thundery showers  Afternoon thundery showers
# 3  2022-03-31T184049  Afternoon thundery showers  Afternoon thundery showers
# 4  2022-03-31T184625  Afternoon thundery showers  Afternoon thundery showers
#
#               4day_forecast_3             4day_forecast_4  \
# 0  Afternoon thundery showers  Afternoon thundery showers
# 1  Afternoon thundery showers  Afternoon thundery showers
# 2  Afternoon thundery showers  Afternoon thundery showers
# 3  Afternoon thundery showers  Afternoon thundery showers
# 4  Afternoon thundery showers  Afternoon thundery showers
#
#    4day_temperature_low_1  4day_temperature_low_2  4day_temperature_low_3  \
# 0                      24                      24                      24
# 1                      24                      24                      24
# 2                      24                      24                      24
# 3                      24                      24                      24
# 4                      24                      24                      24
#
#    4day_temperature_low_4  4day_temperature_high_1  ...  \
# 0                      24                       34  ...
# 1                      24                       34  ...
# 2                      24                       34  ...
# 3                      24                       34  ...
# 4                      24                       34  ...
#
#    4day_wind_speed_low_3  4day_wind_speed_low_4  4day_wind_speed_high_1  \
# 0                      5                      5                      15
# 1                      5                      5                      15
# 2                      5                      5                      15
# 3                      5                      5                      15
# 4                      5                      5                      15
#
#    4day_wind_speed_high_2  4day_wind_speed_high_3  4day_wind_speed_high_4  \
# 0                      15                      15                      15
# 1                      15                      15                      15
# 2                      15                      15                      15
# 3                      15                      15                      15
# 4                      15                      15                      15
#
#    4day_wind_direction_1  4day_wind_direction_2  4day_wind_direction_3  \
# 0                     NW                     NW                      W
# 1                     NW                     NW                      W
# 2                     NW                     NW                      W
# 3                     NW                     NW                      W
# 4                     NW                     NW                      W
#
#    4day_wind_direction_4
# 0                      W
# 1                      W
# 2                      W
# 3                      W
# 4                      W
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 24 Hour Forecast
#
# No processing needed. But got NA to drop

# %%
forecast_24h.head()
# Out:
#           24hr_start           24hr_end 24hr_general_forecast  \
# 0  2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 1  2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 2  2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 3  2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 4  2022-03-31T180000  2022-04-01T180000      Thundery Showers
#
#    24hr_general_relative_humidity_low  24hr_general_relative_humidity_high  \
# 0                                  60                                   95
# 1                                  60                                   95
# 2                                  60                                   95
# 3                                  60                                   95
# 4                                  60                                   95
#
#    24hr_general_temperature_low  24hr_general_temperature_high  \
# 0                            24                             34
# 1                            24                             34
# 2                            24                             34
# 3                            24                             34
# 4                            24                             34
#
#    24hr_general_wind_speed_low  24hr_general_wind_speed_high  \
# 0                           10                            20
# 1                           10                            20
# 2                           10                            20
# 3                           10                            20
# 4                           10                            20
#
#   24hr_general_wind_direction  ... 24hr_period_3_forecast_south  \
# 0                          NW  ...             Thundery Showers
# 1                          NW  ...             Thundery Showers
# 2                          NW  ...             Thundery Showers
# 3                          NW  ...             Thundery Showers
# 4                          NW  ...             Thundery Showers
#
#   24hr_period_3_forecast_north     call_timestamp 24hr_period_4_start  \
# 0             Thundery Showers  2022-03-31T223549                 NaN
# 1             Thundery Showers  2022-03-31T223627                 NaN
# 2             Thundery Showers  2022-03-31T225031                 NaN
# 3             Thundery Showers  2022-03-31T225533                 NaN
# 4             Thundery Showers  2022-03-31T230035                 NaN
#
#   24hr_period_4_end 24hr_period_4_forecast_west 24hr_period_4_forecast_east  \
# 0               NaN                         NaN                         NaN
# 1               NaN                         NaN                         NaN
# 2               NaN                         NaN                         NaN
# 3               NaN                         NaN                         NaN
# 4               NaN                         NaN                         NaN
#
#   24hr_period_4_forecast_central 24hr_period_4_forecast_south  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   24hr_period_4_forecast_north
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 39 columns]

# %%
forecast_24h.isnull().any()
# Out:
# 24hr_start                             False
# 24hr_end                               False
# 24hr_general_forecast                  False
# 24hr_general_relative_humidity_low     False
# 24hr_general_relative_humidity_high    False
# 24hr_general_temperature_low           False
# 24hr_general_temperature_high          False
# 24hr_general_wind_speed_low            False
# 24hr_general_wind_speed_high           False
# 24hr_general_wind_direction            False
# 24hr_period_1_start                    False
# 24hr_period_1_end                      False
# 24hr_period_1_forecast_west            False
# 24hr_period_1_forecast_east            False
# 24hr_period_1_forecast_central         False
# 24hr_period_1_forecast_south           False
# 24hr_period_1_forecast_north           False
# 24hr_period_2_start                    False
# 24hr_period_2_end                      False
# 24hr_period_2_forecast_west            False
# 24hr_period_2_forecast_east            False
# 24hr_period_2_forecast_central         False
# 24hr_period_2_forecast_south           False
# 24hr_period_2_forecast_north           False
# 24hr_period_3_start                    False
# 24hr_period_3_end                      False
# 24hr_period_3_forecast_west            False
# 24hr_period_3_forecast_east            False
# 24hr_period_3_forecast_central         False
# 24hr_period_3_forecast_south           False
# 24hr_period_3_forecast_north           False
# call_timestamp                         False
# 24hr_period_4_start                     True
# 24hr_period_4_end                       True
# 24hr_period_4_forecast_west             True
# 24hr_period_4_forecast_east             True
# 24hr_period_4_forecast_central          True
# 24hr_period_4_forecast_south            True
# 24hr_period_4_forecast_north            True
# dtype: bool

# %%
forecast_24h = forecast_24h.drop(["24hr_period_4_start", "24hr_period_4_end", "24hr_period_4_forecast_west", 
                                 "24hr_period_4_forecast_east", "24hr_period_4_forecast_central", 
                                 "24hr_period_4_forecast_south", "24hr_period_4_forecast_north"], axis = 1)

# %%
forecast_24h
# Out:
#             24hr_start           24hr_end 24hr_general_forecast  \
# 0    2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 1    2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 2    2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 3    2022-03-31T180000  2022-04-01T180000      Thundery Showers
# 4    2022-03-31T180000  2022-04-01T180000      Thundery Showers
# ..                 ...                ...                   ...
# 730  2022-04-03T060000  2022-04-04T060000      Thundery Showers
# 731  2022-04-03T060000  2022-04-04T060000      Thundery Showers
# 732  2022-04-03T060000  2022-04-04T060000      Thundery Showers
# 733  2022-04-03T060000  2022-04-04T060000      Thundery Showers
# 734  2022-04-03T060000  2022-04-04T060000      Thundery Showers
#
#      24hr_general_relative_humidity_low  24hr_general_relative_humidity_high  \
# 0                                    60                                   95
# 1                                    60                                   95
# 2                                    60                                   95
# 3                                    60                                   95
# 4                                    60                                   95
# ..                                  ...                                  ...
# 730                                  60                                   95
# 731                                  60                                   95
# 732                                  60                                   95
# 733                                  60                                   95
# 734                                  60                                   95
#
#      24hr_general_temperature_low  24hr_general_temperature_high  \
# 0                              24                             34
# 1                              24                             34
# 2                              24                             34
# 3                              24                             34
# 4                              24                             34
# ..                            ...                            ...
# 730                            24                             34
# 731                            24                             34
# 732                            24                             34
# 733                            24                             34
# 734                            24                             34
#
#      24hr_general_wind_speed_low  24hr_general_wind_speed_high  \
# 0                             10                            20
# 1                             10                            20
# 2                             10                            20
# 3                             10                            20
# 4                             10                            20
# ..                           ...                           ...
# 730                            5                            15
# 731                            5                            15
# 732                            5                            15
# 733                            5                            15
# 734                            5                            15
#
#     24hr_general_wind_direction  ... 24hr_period_2_forecast_south  \
# 0                            NW  ...          Partly Cloudy (Day)
# 1                            NW  ...          Partly Cloudy (Day)
# 2                            NW  ...          Partly Cloudy (Day)
# 3                            NW  ...          Partly Cloudy (Day)
# 4                            NW  ...          Partly Cloudy (Day)
# ..                          ...  ...                          ...
# 730                          NW  ...             Thundery Showers
# 731                          NW  ...             Thundery Showers
# 732                          NW  ...             Thundery Showers
# 733                          NW  ...             Thundery Showers
# 734                          NW  ...             Thundery Showers
#
#     24hr_period_2_forecast_north 24hr_period_3_start  24hr_period_3_end  \
# 0            Partly Cloudy (Day)   2022-04-01T120000  2022-04-01T180000
# 1            Partly Cloudy (Day)   2022-04-01T120000  2022-04-01T180000
# 2            Partly Cloudy (Day)   2022-04-01T120000  2022-04-01T180000
# 3            Partly Cloudy (Day)   2022-04-01T120000  2022-04-01T180000
# 4            Partly Cloudy (Day)   2022-04-01T120000  2022-04-01T180000
# ..                           ...                 ...                ...
# 730             Thundery Showers   2022-04-03T180000  2022-04-04T060000
# 731             Thundery Showers   2022-04-03T180000  2022-04-04T060000
# 732             Thundery Showers   2022-04-03T180000  2022-04-04T060000
# 733             Thundery Showers   2022-04-03T180000  2022-04-04T060000
# 734             Thundery Showers   2022-04-03T180000  2022-04-04T060000
#
#     24hr_period_3_forecast_west 24hr_period_3_forecast_east  \
# 0              Thundery Showers            Thundery Showers
# 1              Thundery Showers            Thundery Showers
# 2              Thundery Showers            Thundery Showers
# 3              Thundery Showers            Thundery Showers
# 4              Thundery Showers            Thundery Showers
# ..                          ...                         ...
# 730       Partly Cloudy (Night)       Partly Cloudy (Night)
# 731       Partly Cloudy (Night)       Partly Cloudy (Night)
# 732       Partly Cloudy (Night)       Partly Cloudy (Night)
# 733       Partly Cloudy (Night)       Partly Cloudy (Night)
# 734       Partly Cloudy (Night)       Partly Cloudy (Night)
#
#     24hr_period_3_forecast_central 24hr_period_3_forecast_south  \
# 0                 Thundery Showers             Thundery Showers
# 1                 Thundery Showers             Thundery Showers
# 2                 Thundery Showers             Thundery Showers
# 3                 Thundery Showers             Thundery Showers
# 4                 Thundery Showers             Thundery Showers
# ..                             ...                          ...
# 730          Partly Cloudy (Night)        Partly Cloudy (Night)
# 731          Partly Cloudy (Night)        Partly Cloudy (Night)
# 732          Partly Cloudy (Night)        Partly Cloudy (Night)
# 733          Partly Cloudy (Night)        Partly Cloudy (Night)
# 734          Partly Cloudy (Night)        Partly Cloudy (Night)
#
#     24hr_period_3_forecast_north     call_timestamp
# 0               Thundery Showers  2022-03-31T223549
# 1               Thundery Showers  2022-03-31T223627
# 2               Thundery Showers  2022-03-31T225031
# 3               Thundery Showers  2022-03-31T225533
# 4               Thundery Showers  2022-03-31T230035
# ..                           ...                ...
# 730        Partly Cloudy (Night)  2022-04-03T100302
# 731        Partly Cloudy (Night)  2022-04-03T100814
# 732        Partly Cloudy (Night)  2022-04-03T101329
# 733        Partly Cloudy (Night)  2022-04-03T101843
# 734        Partly Cloudy (Night)  2022-04-03T102355
#
# [735 rows x 32 columns]

# %% [markdown]
# ## 2 Hour Forecast

# %%
forecast_2h.head()
# Out:
#   2hr_forecast_area 2hr_forecast_area_loc 2hr_forecast_value  \
# 0        Ang Mo Kio      (1.375, 103.839)             Cloudy
# 1             Bedok      (1.321, 103.924)             Cloudy
# 2            Bishan   (1.350772, 103.839)             Cloudy
# 3          Boon Lay      (1.304, 103.701)             Cloudy
# 4       Bukit Batok      (1.353, 103.754)             Cloudy
#
#            2hr_start            2hr_end     call_timestamp
# 0  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549
# 1  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549
# 2  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549
# 3  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549
# 4  2022-03-31T220000  2022-04-01T000000  2022-03-31T223549

# %%
forecast_2h = forecast_2h.drop(["2hr_forecast_area_loc", "2hr_start", "2hr_end"], axis = 1)
forecast_2h.head()
# Out:
#   2hr_forecast_area 2hr_forecast_value     call_timestamp
# 0        Ang Mo Kio             Cloudy  2022-03-31T223549
# 1             Bedok             Cloudy  2022-03-31T223549
# 2            Bishan             Cloudy  2022-03-31T223549
# 3          Boon Lay             Cloudy  2022-03-31T223549
# 4       Bukit Batok             Cloudy  2022-03-31T223549

# %% [markdown]
# ## Bing Data

# %%
unique_directions = bing_data[["camera_id", "direction"]].rename(columns = {"camera_id" : "cam_id"}).drop_duplicates()

# %%
bing_data = bing_data[["camera_id", "direction", "trafficCongestion", "travelDistance", 
                       "travelDuration", "travelDurationTraffic", "call_timestamp"]]\
.rename(columns = {"camera_id" : "cam_id"})
bing_data.head()
# Out:
#    cam_id  direction trafficCongestion  travelDistance  travelDuration  \
# 0    1704          1             Heavy           0.105               7
# 1    1704          2              Mild           0.127               7
# 2    1704          3             Heavy           0.117               5
# 3    1704          4             Heavy           0.114               5
# 4    1705          1              None           0.214               9
#
#    travelDurationTraffic     call_timestamp
# 0                     13  2022-04-03T105710
# 1                      8  2022-04-03T105710
# 2                      8  2022-04-03T105710
# 3                      8  2022-04-03T105710
# 4                      9  2022-04-03T105710

# %%
bing_data["ratio"] = bing_data.travelDurationTraffic / bing_data.travelDuration

# %%
bing_data[["trafficCongestion", "ratio"]].groupby("trafficCongestion").agg([min, max, np.mean])
# Out:
#                       ratio
#                         min       max      mean
# trafficCongestion
# Heavy              1.500000  4.937500  2.370663
# Medium             1.250000  1.400000  1.308333
# Mild               1.142857  1.200000  1.178144
# None               0.228814  1.090909  0.825089

# %% [markdown]
# So basically clear case of correlated variables

# %% [markdown]
# # Combining Tables
#
# Logic would be to first gather all the time that EVERY dataset has.
# This is to allow for it to be able to join all table.
# Also need to expand the camera mapping

# %%
cam_all = cam_to_loc.merge(unique_directions, on = "cam_id")

# %%
# Based on shimar, the time should all be consistent 
# But this is done just for precaution

all_time = set(rainfall_realtime.call_timestamp)\
.intersection(set(non_rainfall_realtime.call_timestamp))\
.intersection(set(forecast_4d.call_timestamp))\
.intersection(set(forecast_24h.call_timestamp))\
.intersection(set(forecast_2h.call_timestamp))#\
#.intersection(set(bing_data.call_timestamp))

# %%
all_time = pd.DataFrame(all_time, columns = ["call_timestamp"])

# %% [markdown]
# Next step is to cross join this with the camera.
# All cameras should have entries for all time.

# %%
base_df = all_time.merge(cam_to_loc, how = "cross")

# %%
base_df
# Out:
#           call_timestamp  cam_id non_rainfall_station_id rainfall_station_id  \
# 0      2022-04-01T070448    1001                    S108                S119
# 1      2022-04-01T070448    1002                    S108                S215
# 2      2022-04-01T070448    1003                    S108                S123
# 3      2022-04-01T070448    1004                    S108                S215
# 4      2022-04-01T070448    1005                    S107                S221
# ...                  ...     ...                     ...                 ...
# 63853  2022-03-31T200952    9702                    S108                 S08
# 63854  2022-03-31T200952    9703                     S44                S211
# 63855  2022-03-31T200952    9704                     S44                 S40
# 63856  2022-03-31T200952    9705                     S44                S104
# 63857  2022-03-31T200952    9706                     S44                 S40
#
#              2hr_forecast_area
# 0                      Kallang
# 1                      Geylang
# 2                      Kallang
# 3                      Kallang
# 4                   Paya Lebar
# ...                        ...
# 63853  Central Water Catchment
# 63854             Sungei Kadut
# 63855                   Mandai
# 63856                   Mandai
# 63857                   Mandai
#
# [63858 rows x 5 columns]

# %%
df = base_df.merge(rainfall_realtime, on = ["call_timestamp", "rainfall_station_id"], how = "left")

# %%
len(df) == len(base_df)
# Out:
# True

# %%
df2 = df.merge(non_rainfall_realtime, on = ["call_timestamp", "non_rainfall_station_id"], how = "left")

# %%
len(df2) == len(base_df)
# Out:
# True

# %%
df3 = df2.merge(forecast_2h, on = ["call_timestamp", "2hr_forecast_area"], how = "left")

# %%
len(df3) == len(base_df)
# Out:
# True

# %%
df4 = df3.merge(forecast_4d, on = ["call_timestamp"])

# %%
len(df4) == len(base_df)
# Out:
# True

# %% [markdown]
# Left to merge the 24h forecast
# bing data needs the correct time input
