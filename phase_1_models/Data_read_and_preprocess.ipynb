# %% [markdown]
# # Abstracted Form

# %%
from get_files_dynamic import get_super_table
import time
import sys

# %%
tic = time.perf_counter()
quick_pull = get_super_table()
toc = time.perf_counter()
print(f"Got the super table in {toc - tic:0.4f} seconds")
# Out:
# Got the super table in 3.6552 seconds

# %%
sys.getsizeof(quick_pull) / (10**9)
# Out:
# 0.383447669

# %%
from helper import get_req_handler, initBoto3Session, get_s3_objs
from dotenv import load_dotenv
import boto3
import os
from io import StringIO

import pandas as pd
import numpy as np

# %% [markdown]
# # Set Up

# %%
load_dotenv()

aws_access_key_id=os.environ["AWS_ACCESS_KEY_ID"]
aws_secret_access_key=os.environ["AWS_SECRET_ACCESS_KEY"]

client = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)

bucket_name = os.environ["BUCKET_NAME"]
weather_dir = os.environ["WEATHER_DIR"]
bing_dir = os.environ["BING_DIR"]

# %%
def get_csv(file_name, data_dir):
    csv_obj = client.get_object(Bucket=bucket_name, Key= data_dir + file_name)
    body = csv_obj['Body']
    csv_string = body.read().decode('utf-8')
    df = pd.read_csv(StringIO(csv_string))
    df = df.drop("Unnamed: 0", axis = 1)
    return df

# %% [markdown]
# # Camera to Location Map

# %%
cam_to_loc = df = get_csv("camera_station_mapping.csv", "").rename(
    columns = {"rainfall" : "rainfall_station_id",
               "not_rainfall" : "non_rainfall_station_id",
               "region" : "2hr_forecast_area"})
cam_to_loc.head()
# Out:
#    cam_id non_rainfall_station_id rainfall_station_id 2hr_forecast_area  \
# 0    1001                    S108                S119           Kallang
# 1    1002                    S108                S215           Geylang
# 2    1003                    S108                S123           Kallang
# 3    1004                    S108                S215           Kallang
# 4    1005                    S107                S221        Paya Lebar
#
#    compass
# 0    south
# 1     east
# 2  central
# 3  central
# 4     east

# %% [markdown]
# # Read Files
#
# IMPORTANT: Note all data will be consistent (sometime the stations wont appear)
# Time stamps are also different - shimar looking into it

# %%
rainfall_realtime = get_csv("rainfall-realtime.csv", weather_dir)
rainfall_realtime.head()
# Out:
#            timestamp station_id         station_loc            station_name  \
# 0  2022-04-07T100000        S77  (1.2937, 103.8125)          Alexandra Road
# 1  2022-04-07T100000       S109  (1.3764, 103.8492)     Ang Mo Kio Avenue 5
# 2  2022-04-07T100000        S90  (1.3191, 103.8191)        Bukit Timah Road
# 3  2022-04-07T100000       S114      (1.38, 103.73)  Choa Chu Kang Avenue 4
# 4  2022-04-07T100000        S50  (1.3337, 103.7768)           Clementi Road
#
#    rainfall_realtime     call_timestamp
# 0                0.0  2022-04-07T101422
# 1                0.0  2022-04-07T101422
# 2                0.0  2022-04-07T101422
# 3                0.0  2022-04-07T101422
# 4                0.0  2022-04-07T101422

# %%
non_rainfall_realtime = get_csv("non-rainfall-realtime.csv", weather_dir)
non_rainfall_realtime.head()
# Out:
#            timestamp station_id           station_loc  \
# 0  2022-04-07T101000       S107    (1.3135, 103.9625)
# 1  2022-04-07T101000        S44  (1.34583, 103.68166)
# 2  2022-04-07T101000        S24    (1.3678, 103.9826)
# 3  2022-04-07T101500       S107    (1.3135, 103.9625)
# 4  2022-04-07T101500        S44  (1.34583, 103.68166)
#
#               station_name  wind_speed_realtime  wind_dir_realtime  \
# 0       East Coast Parkway                 11.9              220.0
# 1           Nanyang Avenue                  5.2              205.0
# 2  Upper Changi Road North                  4.0              281.0
# 3       East Coast Parkway                 11.2              225.0
# 4           Nanyang Avenue                  5.2              206.0
#
#       call_timestamp  RH%_realtime  air_temp_realtime
# 0  2022-04-07T101422           NaN                NaN
# 1  2022-04-07T101422           NaN                NaN
# 2  2022-04-07T101422           NaN                NaN
# 3  2022-04-07T102045          82.4               26.5
# 4  2022-04-07T102045          87.8               24.9

# %%
non_rainfall_realtime.station_id.unique()
# Out:
# array(['S107', 'S44', 'S24', 'S116', 'S50', 'S100'], dtype=object)

# %%
non_rainfall_realtime[["station_id", "call_timestamp"]].groupby("station_id").count()
# Out:
#             call_timestamp
# station_id
# S100                     1
# S107                   915
# S116                     6
# S24                    862
# S44                    250
# S50                    123

# %%
non_rainfall_realtime.dropna()[["station_id", "call_timestamp"]].groupby("station_id").count()
# Out:
#             call_timestamp
# station_id
# S100                     1
# S107                   884
# S116                     6
# S24                    835
# S44                    240
# S50                    120

# %%
len(non_rainfall_realtime.call_timestamp.unique())
# Out:
# 901

# %%
non_rainfall_realtime[non_rainfall_realtime.call_timestamp == "2022-04-05T162939"]
# Out:
# Empty DataFrame
# Columns: [timestamp, station_id, station_loc, station_name, wind_speed_realtime, wind_dir_realtime, call_timestamp, RH%_realtime, air_temp_realtime]
# Index: []

# %%
forecast_4d = get_csv("forecast-4DAY.csv", weather_dir)
forecast_4d.head()
# Out:
#            4day_date                                4day_forecast  \
# 0  2022-04-08T000000  Pre-dawn and early morning thundery showers
# 1  2022-04-09T000000                   Afternoon thundery showers
# 2  2022-04-10T000000                   Afternoon thundery showers
# 3  2022-04-11T000000                     Morning thundery showers
# 4  2022-04-08T000000  Pre-dawn and early morning thundery showers
#
#    4day_temperature_low  4day_temperature_high  4day_relative_humidity_low  \
# 0                    23                     33                          60
# 1                    24                     34                          60
# 2                    24                     34                          55
# 3                    23                     33                          55
# 4                    23                     33                          60
#
#    4day_relative_humidity_high  4day_wind_speed_low  4day_wind_speed_high  \
# 0                           95                   10                    20
# 1                           95                   10                    20
# 2                           95                    5                    15
# 3                           95                    5                    15
# 4                           95                   10                    20
#
#   4day_wind_direction 4day_update_timestamp     call_timestamp
# 0                   W     2022-04-07T043212  2022-04-07T101422
# 1                   W     2022-04-07T043212  2022-04-07T101422
# 2                   W     2022-04-07T043212  2022-04-07T101422
# 3                  SW     2022-04-07T043212  2022-04-07T101422
# 4                   W     2022-04-07T043212  2022-04-07T102045

# %%
forecast_24h = get_csv("forecast-24HR.csv", weather_dir)
forecast_24h.head()
# Out:
#           24hr_start           24hr_end 24hr_general_forecast  \
# 0  2022-04-07T060000  2022-04-08T060000               Showers
# 1  2022-04-07T060000  2022-04-08T060000               Showers
# 2  2022-04-07T060000  2022-04-08T060000               Showers
# 3  2022-04-07T060000  2022-04-08T060000               Showers
# 4  2022-04-07T060000  2022-04-08T060000               Showers
#
#    24hr_general_relative_humidity_low  24hr_general_relative_humidity_high  \
# 0                                  60                                   95
# 1                                  60                                   95
# 2                                  60                                   95
# 3                                  60                                   95
# 4                                  60                                   95
#
#    24hr_general_temperature_low  24hr_general_temperature_high  \
# 0                            24                             33
# 1                            24                             33
# 2                            24                             33
# 3                            24                             33
# 4                            24                             33
#
#    24hr_general_wind_speed_low  24hr_general_wind_speed_high  \
# 0                            5                            15
# 1                            5                            15
# 2                            5                            15
# 3                            5                            15
# 4                            5                            15
#
#   24hr_general_wind_direction  ... 24hr_period_2_forecast_south  \
# 0                          NW  ...          Partly Cloudy (Day)
# 1                          NW  ...          Partly Cloudy (Day)
# 2                          NW  ...          Partly Cloudy (Day)
# 3                          NW  ...          Partly Cloudy (Day)
# 4                          NW  ...          Partly Cloudy (Day)
#
#   24hr_period_2_forecast_north 24hr_period_3_start  24hr_period_3_end  \
# 0          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
# 1          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
# 2          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
# 3          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
# 4          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
#
#   24hr_period_3_forecast_west 24hr_period_3_forecast_east  \
# 0                      Cloudy                      Cloudy
# 1                      Cloudy                      Cloudy
# 2                      Cloudy                      Cloudy
# 3                      Cloudy                      Cloudy
# 4                      Cloudy                      Cloudy
#
#   24hr_period_3_forecast_central 24hr_period_3_forecast_south  \
# 0                         Cloudy                       Cloudy
# 1                         Cloudy                       Cloudy
# 2                         Cloudy                       Cloudy
# 3                         Cloudy                       Cloudy
# 4                         Cloudy                       Cloudy
#
#   24hr_period_3_forecast_north     call_timestamp
# 0                       Cloudy  2022-04-07T101422
# 1                       Cloudy  2022-04-07T102045
# 2                       Cloudy  2022-04-07T102706
# 3                       Cloudy  2022-04-07T103335
# 4                       Cloudy  2022-04-07T103957
#
# [5 rows x 32 columns]

# %%
forecast_2h = get_csv("forecast-2HR.csv", weather_dir)
forecast_2h.head()
# Out:
#   2hr_forecast_area 2hr_forecast_area_loc 2hr_forecast_value  \
# 0        Ang Mo Kio      (1.375, 103.839)            Showers
# 1             Bedok      (1.321, 103.924)            Showers
# 2            Bishan   (1.350772, 103.839)            Showers
# 3          Boon Lay      (1.304, 103.701)            Showers
# 4       Bukit Batok      (1.353, 103.754)            Showers
#
#            2hr_start            2hr_end     call_timestamp
# 0  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422
# 1  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422
# 2  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422
# 3  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422
# 4  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422

# %%
bing_data = get_csv("all-congestion-levels.csv", bing_dir)
bing_data.head()
# Out:
#    camera_id  direction trafficCongestion  travelDistance  travelDuration  \
# 0       1001          1              None           0.100               4
# 1       1001          2              None           0.099               4
# 2       1002          1              Mild           0.099               5
# 3       1002          2            Medium           0.100               4
# 4       1003          1              None           0.105               6
#
#    travelDurationTraffic distanceUnit durationUnit     call_timestamp  \
# 0                      3    Kilometer       Second  2022-04-07T101422
# 1                      3    Kilometer       Second  2022-04-07T101422
# 2                      6    Kilometer       Second  2022-04-07T101422
# 3                      5    Kilometer       Second  2022-04-07T101422
# 4                      5    Kilometer       Second  2022-04-07T101422
#
#                       cam_loc            remarks  \
# 0    (1.29531332, 103.871146)        TRUE (left)
# 1    (1.29531332, 103.871146)        TRUE (left)
# 2  (1.319541067, 103.8785627)        TRUE (left)
# 3  (1.319541067, 103.8785627)        TRUE (left)
# 4  (1.323957439, 103.8728576)  SPECIAL (5 lanes)
#
#                                   dir_start  \
# 0  (1.2952719096725678, 103.87068089160921)
# 1   (1.295216922089859, 103.87161591936747)
# 2   (1.319649819147653, 103.87894320461515)
# 3    (1.319965499763606, 103.8780229770321)
# 4  (1.3243485357876017, 103.87259422178255)
#
#                                  dir_finish
# 0  (1.2954046383155724, 103.87157229738281)
# 1    (1.29509936242626, 103.87072261698584)
# 2  (1.3195731538491529, 103.87805455346877)
# 3    (1.320015106713897, 103.8789296718566)
# 4  (1.3236450201732457, 103.87318289678052)

# %%
bing_key_table = get_csv("route_data.csv", bing_dir)
bing_key_table.head()
# Out:
#    camera_id  direction                     cam_loc            remarks  \
# 0       1001          1    (1.29531332, 103.871146)        TRUE (left)
# 1       1001          2    (1.29531332, 103.871146)        TRUE (left)
# 2       1002          1  (1.319541067, 103.8785627)        TRUE (left)
# 3       1002          2  (1.319541067, 103.8785627)        TRUE (left)
# 4       1003          1  (1.323957439, 103.8728576)  SPECIAL (5 lanes)
#
#                                   dir_start  \
# 0  (1.2952719096725678, 103.87068089160921)
# 1   (1.295216922089859, 103.87161591936747)
# 2   (1.319649819147653, 103.87894320461515)
# 3    (1.319965499763606, 103.8780229770321)
# 4  (1.3243485357876017, 103.87259422178255)
#
#                                  dir_finish
# 0  (1.2954046383155724, 103.87157229738281)
# 1    (1.29509936242626, 103.87072261698584)
# 2  (1.3195731538491529, 103.87805455346877)
# 3    (1.320015106713897, 103.8789296718566)
# 4  (1.3236450201732457, 103.87318289678052)

# %% [markdown]
# # Processing
#
# So the objective here is to make the dataset into a useable one - ie the whole long row as we would input into a model
# Chances are going to have to process individually.
# The superkey to join all tables will be the timestamp except forecast idk how that will work
#
# ## Realtime Rainfall

# %%
# original view
rainfall_realtime.head()
# Out:
#            timestamp station_id         station_loc            station_name  \
# 0  2022-04-07T100000        S77  (1.2937, 103.8125)          Alexandra Road
# 1  2022-04-07T100000       S109  (1.3764, 103.8492)     Ang Mo Kio Avenue 5
# 2  2022-04-07T100000        S90  (1.3191, 103.8191)        Bukit Timah Road
# 3  2022-04-07T100000       S114      (1.38, 103.73)  Choa Chu Kang Avenue 4
# 4  2022-04-07T100000        S50  (1.3337, 103.7768)           Clementi Road
#
#    rainfall_realtime     call_timestamp
# 0                0.0  2022-04-07T101422
# 1                0.0  2022-04-07T101422
# 2                0.0  2022-04-07T101422
# 3                0.0  2022-04-07T101422
# 4                0.0  2022-04-07T101422

# %%
rainfall_realtime = rainfall_realtime[["call_timestamp", "station_id", "rainfall_realtime"]]
rainfall_realtime = rainfall_realtime.rename(columns = {"station_id" : "rainfall_station_id"})
rainfall_realtime.head()
# Out:
#       call_timestamp rainfall_station_id  rainfall_realtime
# 0  2022-04-07T101422                 S77                0.0
# 1  2022-04-07T101422                S109                0.0
# 2  2022-04-07T101422                 S90                0.0
# 3  2022-04-07T101422                S114                0.0
# 4  2022-04-07T101422                 S50                0.0

# %% [markdown]
# ## Realtime non rainfall

# %%
non_rainfall_realtime.head()
# Out:
#            timestamp station_id           station_loc  \
# 0  2022-04-07T101000       S107    (1.3135, 103.9625)
# 1  2022-04-07T101000        S44  (1.34583, 103.68166)
# 2  2022-04-07T101000        S24    (1.3678, 103.9826)
# 3  2022-04-07T101500       S107    (1.3135, 103.9625)
# 4  2022-04-07T101500        S44  (1.34583, 103.68166)
#
#               station_name  wind_speed_realtime  wind_dir_realtime  \
# 0       East Coast Parkway                 11.9                220
# 1           Nanyang Avenue                  5.2                205
# 2  Upper Changi Road North                  4.0                281
# 3       East Coast Parkway                 11.2                225
# 4           Nanyang Avenue                  5.2                206
#
#       call_timestamp  RH%_realtime  air_temp_realtime
# 0  2022-04-07T101422           NaN                NaN
# 1  2022-04-07T101422           NaN                NaN
# 2  2022-04-07T101422           NaN                NaN
# 3  2022-04-07T102045          82.4               26.5
# 4  2022-04-07T102045          87.8               24.9

# %%
non_rainfall_realtime = non_rainfall_realtime.rename(columns = {"RH%_realtime" : "humidity_realtime", 
                                                               "station_id" : "non_rainfall_station_id"})

# %%
non_rainfall_realtime = non_rainfall_realtime[["call_timestamp", "non_rainfall_station_id", "wind_speed_realtime", 
                                               "wind_dir_realtime", "humidity_realtime", "air_temp_realtime"]]
non_rainfall_realtime.head()
# Out:
#       call_timestamp non_rainfall_station_id  wind_speed_realtime  \
# 0  2022-04-07T101422                    S107                 11.9
# 1  2022-04-07T101422                     S44                  5.2
# 2  2022-04-07T101422                     S24                  4.0
# 3  2022-04-07T102045                    S107                 11.2
# 4  2022-04-07T102045                     S44                  5.2
#
#    wind_dir_realtime  humidity_realtime  air_temp_realtime
# 0                220                NaN                NaN
# 1                205                NaN                NaN
# 2                281                NaN                NaN
# 3                225               82.4               26.5
# 4                206               87.8               24.9

# %% [markdown]
# ## 4 Day Forecast

# %%
forecast_4d["4day_date"] = pd.to_datetime(forecast_4d["4day_date"])
forecast_4d["grp_row_num"] = forecast_4d.sort_values("4day_date").groupby(["4day_update_timestamp", "call_timestamp"])["4day_date"].cumcount()+1
forecast_4d["grp_row_num"] = forecast_4d.grp_row_num.apply(lambda x : str(x))
forecast_4d = forecast_4d.drop("4day_date", axis = 1)
forecast_4d = forecast_4d.pivot(index = "call_timestamp", columns = "grp_row_num")
forecast_4d.columns = ['_'.join(col) for col in forecast_4d.columns]
forecast_4d = forecast_4d.drop(["4day_update_timestamp_1", "4day_update_timestamp_2", 
                  "4day_update_timestamp_3", "4day_update_timestamp_4"], axis = 1)
forecast_4d = forecast_4d.reset_index()
forecast_4d.head()
# Out:
#       call_timestamp                              4day_forecast_1  \
# 0  2022-04-07T101422  Pre-dawn and early morning thundery showers
# 1  2022-04-07T102045  Pre-dawn and early morning thundery showers
# 2  2022-04-07T102706  Pre-dawn and early morning thundery showers
# 3  2022-04-07T103335  Pre-dawn and early morning thundery showers
# 4  2022-04-07T103957  Pre-dawn and early morning thundery showers
#
#               4day_forecast_2             4day_forecast_3  \
# 0  Afternoon thundery showers  Afternoon thundery showers
# 1  Afternoon thundery showers  Afternoon thundery showers
# 2  Afternoon thundery showers  Afternoon thundery showers
# 3  Afternoon thundery showers  Afternoon thundery showers
# 4  Afternoon thundery showers  Afternoon thundery showers
#
#             4day_forecast_4  4day_temperature_low_1  4day_temperature_low_2  \
# 0  Morning thundery showers                      23                      24
# 1  Morning thundery showers                      23                      24
# 2  Morning thundery showers                      23                      24
# 3  Morning thundery showers                      23                      24
# 4  Morning thundery showers                      23                      24
#
#    4day_temperature_low_3  4day_temperature_low_4  4day_temperature_high_1  \
# 0                      24                      23                       33
# 1                      24                      23                       33
# 2                      24                      23                       33
# 3                      24                      23                       33
# 4                      24                      23                       33
#
#    ...  4day_wind_speed_low_3  4day_wind_speed_low_4  4day_wind_speed_high_1  \
# 0  ...                      5                      5                      20
# 1  ...                      5                      5                      20
# 2  ...                      5                      5                      20
# 3  ...                      5                      5                      20
# 4  ...                      5                      5                      20
#
#    4day_wind_speed_high_2  4day_wind_speed_high_3  4day_wind_speed_high_4  \
# 0                      20                      15                      15
# 1                      20                      15                      15
# 2                      20                      15                      15
# 3                      20                      15                      15
# 4                      20                      15                      15
#
#    4day_wind_direction_1  4day_wind_direction_2  4day_wind_direction_3  \
# 0                      W                      W                      W
# 1                      W                      W                      W
# 2                      W                      W                      W
# 3                      W                      W                      W
# 4                      W                      W                      W
#
#    4day_wind_direction_4
# 0                     SW
# 1                     SW
# 2                     SW
# 3                     SW
# 4                     SW
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 24 Hour Forecast
#
# No processing needed. But got NA to drop

# %%
forecast_24h.head()
# Out:
#           24hr_start           24hr_end 24hr_general_forecast  \
# 0  2022-04-07T060000  2022-04-08T060000               Showers
# 1  2022-04-07T060000  2022-04-08T060000               Showers
# 2  2022-04-07T060000  2022-04-08T060000               Showers
# 3  2022-04-07T060000  2022-04-08T060000               Showers
# 4  2022-04-07T060000  2022-04-08T060000               Showers
#
#    24hr_general_relative_humidity_low  24hr_general_relative_humidity_high  \
# 0                                  60                                   95
# 1                                  60                                   95
# 2                                  60                                   95
# 3                                  60                                   95
# 4                                  60                                   95
#
#    24hr_general_temperature_low  24hr_general_temperature_high  \
# 0                            24                             33
# 1                            24                             33
# 2                            24                             33
# 3                            24                             33
# 4                            24                             33
#
#    24hr_general_wind_speed_low  24hr_general_wind_speed_high  \
# 0                            5                            15
# 1                            5                            15
# 2                            5                            15
# 3                            5                            15
# 4                            5                            15
#
#   24hr_general_wind_direction  ... 24hr_period_2_forecast_south  \
# 0                          NW  ...          Partly Cloudy (Day)
# 1                          NW  ...          Partly Cloudy (Day)
# 2                          NW  ...          Partly Cloudy (Day)
# 3                          NW  ...          Partly Cloudy (Day)
# 4                          NW  ...          Partly Cloudy (Day)
#
#   24hr_period_2_forecast_north 24hr_period_3_start  24hr_period_3_end  \
# 0          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
# 1          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
# 2          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
# 3          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
# 4          Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000
#
#   24hr_period_3_forecast_west 24hr_period_3_forecast_east  \
# 0                      Cloudy                      Cloudy
# 1                      Cloudy                      Cloudy
# 2                      Cloudy                      Cloudy
# 3                      Cloudy                      Cloudy
# 4                      Cloudy                      Cloudy
#
#   24hr_period_3_forecast_central 24hr_period_3_forecast_south  \
# 0                         Cloudy                       Cloudy
# 1                         Cloudy                       Cloudy
# 2                         Cloudy                       Cloudy
# 3                         Cloudy                       Cloudy
# 4                         Cloudy                       Cloudy
#
#   24hr_period_3_forecast_north     call_timestamp
# 0                       Cloudy  2022-04-07T101422
# 1                       Cloudy  2022-04-07T102045
# 2                       Cloudy  2022-04-07T102706
# 3                       Cloudy  2022-04-07T103335
# 4                       Cloudy  2022-04-07T103957
#
# [5 rows x 32 columns]

# %%
forecast_24h.isnull().any()
# Out:
# 24hr_start                             False
# 24hr_end                               False
# 24hr_general_forecast                  False
# 24hr_general_relative_humidity_low     False
# 24hr_general_relative_humidity_high    False
# 24hr_general_temperature_low           False
# 24hr_general_temperature_high          False
# 24hr_general_wind_speed_low            False
# 24hr_general_wind_speed_high           False
# 24hr_general_wind_direction            False
# 24hr_period_1_start                    False
# 24hr_period_1_end                      False
# 24hr_period_1_forecast_west            False
# 24hr_period_1_forecast_east            False
# 24hr_period_1_forecast_central         False
# 24hr_period_1_forecast_south           False
# 24hr_period_1_forecast_north           False
# 24hr_period_2_start                    False
# 24hr_period_2_end                      False
# 24hr_period_2_forecast_west            False
# 24hr_period_2_forecast_east            False
# 24hr_period_2_forecast_central         False
# 24hr_period_2_forecast_south           False
# 24hr_period_2_forecast_north           False
# 24hr_period_3_start                    False
# 24hr_period_3_end                      False
# 24hr_period_3_forecast_west            False
# 24hr_period_3_forecast_east            False
# 24hr_period_3_forecast_central         False
# 24hr_period_3_forecast_south           False
# 24hr_period_3_forecast_north           False
# call_timestamp                         False
# dtype: bool

# %%
forecast_24h = forecast_24h.drop(["24hr_period_4_start", "24hr_period_4_end", "24hr_period_4_forecast_west", 
                                 "24hr_period_4_forecast_east", "24hr_period_4_forecast_central", 
                                 "24hr_period_4_forecast_south", "24hr_period_4_forecast_north"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 forecast_24h = forecast_24h.drop(["24hr_period_4_start", "24hr_period_4_end", "24hr_period_4_forecast_west",
#       2                                  "24hr_period_4_forecast_east", "24hr_period_4_forecast_central",
#       3                                  "24hr_period_4_forecast_south", "24hr_period_4_forecast_north"], axis = 1)
#
# File c:\users\vik\desktop\cs 4225\project\traffic-predict\.venv\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\users\vik\desktop\cs 4225\project\traffic-predict\.venv\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
#    4802     self,
#    (...)
#    4809     errors: str = "raise",
#    4810 ):
#    4811     """
#    4812     Drop specified labels from rows or columns.
#    4813
#    (...)
#    4946             weight  1.0     0.8
#    4947     """
# -> 4948     return super().drop(
#    4949         labels=labels,
#    4950         axis=axis,
#    4951         index=index,
#    4952         columns=columns,
#    4953         level=level,
#    4954         inplace=inplace,
#    4955         errors=errors,
#    4956     )
#
# File c:\users\vik\desktop\cs 4225\project\traffic-predict\.venv\lib\site-packages\pandas\core\generic.py:4279, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277 for axis, labels in axes.items():
#    4278     if labels is not None:
# -> 4279         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4281 if inplace:
#    4282     self._update_inplace(obj)
#
# File c:\users\vik\desktop\cs 4225\project\traffic-predict\.venv\lib\site-packages\pandas\core\generic.py:4323, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321         new_axis = axis.drop(labels, level=level, errors=errors)
#    4322     else:
# -> 4323         new_axis = axis.drop(labels, errors=errors)
#    4324     indexer = axis.get_indexer(new_axis)
#    4326 # Case for non-unique axis
#    4327 else:
#
# File c:\users\vik\desktop\cs 4225\project\traffic-predict\.venv\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['24hr_period_4_start', '24hr_period_4_end', '24hr_period_4_forecast_west', '24hr_period_4_forecast_east', '24hr_period_4_forecast_central', '24hr_period_4_forecast_south', '24hr_period_4_forecast_north'] not found in axis"

# %%
long_df1 = pd.melt(forecast_24h, id_vars = ["call_timestamp", "24hr_period_1_start", "24hr_period_1_end"],
        value_vars= ["24hr_period_1_forecast_west", 
                                 "24hr_period_1_forecast_east", "24hr_period_1_forecast_central", 
                                 "24hr_period_1_forecast_south", "24hr_period_1_forecast_north"])

long_df2 = pd.melt(forecast_24h, id_vars = ["call_timestamp", "24hr_period_2_start", "24hr_period_2_end"],
        value_vars= ["24hr_period_2_forecast_west", 
                                 "24hr_period_2_forecast_east", "24hr_period_2_forecast_central", 
                                 "24hr_period_2_forecast_south", "24hr_period_2_forecast_north"])

long_df3 = pd.melt(forecast_24h, id_vars = ["call_timestamp", "24hr_period_3_start", "24hr_period_3_end"],
        value_vars= ["24hr_period_3_forecast_west", 
                                 "24hr_period_3_forecast_east", "24hr_period_3_forecast_central", 
                                 "24hr_period_3_forecast_south", "24hr_period_3_forecast_north"])

# %%
long_df1["compass"] = long_df1.variable.apply(lambda x : x.split("_")[-1])
long_df2["compass"] = long_df2.variable.apply(lambda x : x.split("_")[-1])
long_df3["compass"] = long_df3.variable.apply(lambda x : x.split("_")[-1])

# %%
long_df1 = long_df1.drop("variable", axis = 1).rename(columns = {"value" : "24hr_period_1"})
long_df2 = long_df2.drop("variable", axis = 1).rename(columns = {"value" : "24hr_period_2"})
long_df3 = long_df3.drop("variable", axis = 1).rename(columns = {"value" : "24hr_period_3"})

# %%
forecast_24h = forecast_24h.drop(["24hr_period_1_forecast_west", 
                                 "24hr_period_1_forecast_east", "24hr_period_1_forecast_central", 
                                 "24hr_period_1_forecast_south", "24hr_period_1_forecast_north", 
                                 "24hr_period_2_forecast_west", 
                                 "24hr_period_2_forecast_east", "24hr_period_2_forecast_central", 
                                 "24hr_period_2_forecast_south", "24hr_period_2_forecast_north", 
                                 "24hr_period_3_forecast_west", 
                                 "24hr_period_3_forecast_east", "24hr_period_3_forecast_central", 
                                 "24hr_period_3_forecast_south", "24hr_period_3_forecast_north", 
                                 "24hr_period_1_start", "24hr_period_1_end", 
                                 "24hr_period_2_start", "24hr_period_2_end", 
                                 "24hr_period_3_start", "24hr_period_3_end"], axis = 1)

# %%
forecast_24h = forecast_24h\
.merge(long_df1, how = "inner", on = "call_timestamp")\
.merge(long_df2, how = "inner", on = ["call_timestamp", "compass"])\
.merge(long_df3, how = "inner", on = ["call_timestamp", "compass"])

# %%
forecast_24h.head()
# Out:
#           24hr_start           24hr_end 24hr_general_forecast  \
# 0  2022-04-07T060000  2022-04-08T060000               Showers
# 1  2022-04-07T060000  2022-04-08T060000               Showers
# 2  2022-04-07T060000  2022-04-08T060000               Showers
# 3  2022-04-07T060000  2022-04-08T060000               Showers
# 4  2022-04-07T060000  2022-04-08T060000               Showers
#
#    24hr_general_relative_humidity_low  24hr_general_relative_humidity_high  \
# 0                                  60                                   95
# 1                                  60                                   95
# 2                                  60                                   95
# 3                                  60                                   95
# 4                                  60                                   95
#
#    24hr_general_temperature_low  24hr_general_temperature_high  \
# 0                            24                             33
# 1                            24                             33
# 2                            24                             33
# 3                            24                             33
# 4                            24                             33
#
#    24hr_general_wind_speed_low  24hr_general_wind_speed_high  \
# 0                            5                            15
# 1                            5                            15
# 2                            5                            15
# 3                            5                            15
# 4                            5                            15
#
#   24hr_general_wind_direction  ... 24hr_period_1_start  24hr_period_1_end  \
# 0                          NW  ...   2022-04-07T060000  2022-04-07T120000
# 1                          NW  ...   2022-04-07T060000  2022-04-07T120000
# 2                          NW  ...   2022-04-07T060000  2022-04-07T120000
# 3                          NW  ...   2022-04-07T060000  2022-04-07T120000
# 4                          NW  ...   2022-04-07T060000  2022-04-07T120000
#
#   24hr_period_1  compass 24hr_period_2_start  24hr_period_2_end  \
# 0       Showers     west   2022-04-07T120000  2022-04-07T180000
# 1       Showers     east   2022-04-07T120000  2022-04-07T180000
# 2       Showers  central   2022-04-07T120000  2022-04-07T180000
# 3       Showers    south   2022-04-07T120000  2022-04-07T180000
# 4       Showers    north   2022-04-07T120000  2022-04-07T180000
#
#          24hr_period_2 24hr_period_3_start  24hr_period_3_end 24hr_period_3
# 0  Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000        Cloudy
# 1  Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000        Cloudy
# 2  Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000        Cloudy
# 3  Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000        Cloudy
# 4  Partly Cloudy (Day)   2022-04-07T180000  2022-04-08T060000        Cloudy
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 2 Hour Forecast

# %%
forecast_2h.head()
# Out:
#   2hr_forecast_area 2hr_forecast_area_loc 2hr_forecast_value  \
# 0        Ang Mo Kio      (1.375, 103.839)            Showers
# 1             Bedok      (1.321, 103.924)            Showers
# 2            Bishan   (1.350772, 103.839)            Showers
# 3          Boon Lay      (1.304, 103.701)            Showers
# 4       Bukit Batok      (1.353, 103.754)            Showers
#
#            2hr_start            2hr_end     call_timestamp
# 0  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422
# 1  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422
# 2  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422
# 3  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422
# 4  2022-04-07T100000  2022-04-07T120000  2022-04-07T101422

# %%
forecast_2h = forecast_2h.drop(["2hr_forecast_area_loc", "2hr_start", "2hr_end"], axis = 1)
forecast_2h.head()
# Out:
#   2hr_forecast_area 2hr_forecast_value     call_timestamp
# 0        Ang Mo Kio            Showers  2022-04-07T101422
# 1             Bedok            Showers  2022-04-07T101422
# 2            Bishan            Showers  2022-04-07T101422
# 3          Boon Lay            Showers  2022-04-07T101422
# 4       Bukit Batok            Showers  2022-04-07T101422

# %% [markdown]
# ## Bing Data

# %%
bing_key_table = bing_key_table[["camera_id", "direction"]].rename(columns = {"camera_id" : "cam_id"})

# %%
bing_data = bing_data[["camera_id", "direction", "call_timestamp", "trafficCongestion",
                      "travelDistance", "travelDuration", "travelDurationTraffic"]]\
.rename(columns = {"camera_id" : "cam_id"})

# %%
bing_data["ratio"] = bing_data.travelDurationTraffic / bing_data.travelDuration

# %%
bing_data.head()
# Out:
#    cam_id  direction     call_timestamp trafficCongestion  travelDistance  \
# 0    1001          1  2022-04-07T101422              None           0.100
# 1    1001          2  2022-04-07T101422              None           0.099
# 2    1002          1  2022-04-07T101422              Mild           0.099
# 3    1002          2  2022-04-07T101422            Medium           0.100
# 4    1003          1  2022-04-07T101422              None           0.105
#
#    travelDuration  travelDurationTraffic     ratio
# 0               4                      3  0.750000
# 1               4                      3  0.750000
# 2               5                      6  1.200000
# 3               4                      5  1.250000
# 4               6                      5  0.833333

# %%
bing_data[["trafficCongestion", "ratio"]].groupby("trafficCongestion").agg([min, max, np.mean])
# Out:
#                   ratio
#                     min        max      mean
# trafficCongestion
# Heavy              1.50  12.750000  1.926756
# Medium             1.25   1.464286  1.268546
# Mild               1.10   1.242857  1.184653
# None               0.00   1.096774  0.901675

# %%
bing_data[["trafficCongestion", "cam_id"]].groupby("trafficCongestion").count() # need to look out for unknowns
# Out:
#                    cam_id
# trafficCongestion
# Heavy                1250
# Medium               2258
# Mild                  711
# None                 4552

# %% [markdown]
# So basically clear case of correlated variables

# %%
bing_data[bing_data.trafficCongestion == "Unknown"]
# Out:
# Empty DataFrame
# Columns: [cam_id, direction, call_timestamp, trafficCongestion, travelDistance, travelDuration, travelDurationTraffic, ratio]
# Index: []

# %%
bing_data[bing_data.cam_id == 3702]
# Out:
#       cam_id  direction     call_timestamp trafficCongestion  travelDistance  \
# 57      3702          1  2022-04-07T101422              None           0.201
# 58      3702          2  2022-04-07T101422              None           0.198
# 236     3702          1  2022-04-07T102045              None           0.201
# 237     3702          2  2022-04-07T102045              None           0.198
# 415     3702          1  2022-04-07T102706              None           0.201
# ...      ...        ...                ...               ...             ...
# 8292    3702          2  2022-04-07T150925              None           0.198
# 8470    3702          1  2022-04-07T151546              None           0.201
# 8471    3702          2  2022-04-07T151546              None           0.198
# 8649    3702          1  2022-04-07T152209              None           0.201
# 8650    3702          2  2022-04-07T152209              None           0.198
#
#       travelDuration  travelDurationTraffic  ratio
# 57                 8                      8  1.000
# 58                 8                      7  0.875
# 236                8                      8  1.000
# 237                8                      7  0.875
# 415                8                      8  1.000
# ...              ...                    ...    ...
# 8292               8                      7  0.875
# 8470               8                      8  1.000
# 8471               8                      7  0.875
# 8649               8                      8  1.000
# 8650               8                      7  0.875
#
# [98 rows x 8 columns]

# %%
bing_data = bing_data[["cam_id", "direction", "call_timestamp", "trafficCongestion"]]
##bing_data = bing_data[bing_data.trafficCongestion != "Unknown"]

# %%
bing_data[bing_data.call_timestamp == "2022-04-05T162939"]
# Out:
# Empty DataFrame
# Columns: [cam_id, direction, call_timestamp, trafficCongestion]
# Index: []

# %% [markdown]
# # Combining Tables
#
# Logic would be to first gather all the time that EVERY dataset has.
# This is to allow for it to be able to join all table.
# Also need to expand the camera mapping

# %%
cam_all = cam_to_loc.merge(bing_key_table, on = "cam_id")

# %%
all_time = set(rainfall_realtime.call_timestamp)\
.intersection(set(non_rainfall_realtime.call_timestamp))\
.intersection(set(forecast_4d.call_timestamp))\
.intersection(set(forecast_24h.call_timestamp))\
.intersection(set(forecast_2h.call_timestamp))\
.intersection(set(bing_data.call_timestamp))

# %%
all_time = pd.DataFrame(all_time, columns = ["call_timestamp"])

# %%
all_time.sort_values("call_timestamp")
# Out:
#        call_timestamp
# 24  2022-04-07T101422
# 40  2022-04-07T102045
# 2   2022-04-07T102706
# 48  2022-04-07T103335
# 45  2022-04-07T103957
# 43  2022-04-07T104622
# 42  2022-04-07T105244
# 0   2022-04-07T110012
# 37  2022-04-07T110636
# 44  2022-04-07T111301
# 4   2022-04-07T111925
# 32  2022-04-07T112547
# 26  2022-04-07T113210
# 7   2022-04-07T113832
# 17  2022-04-07T114455
# 47  2022-04-07T115118
# 36  2022-04-07T115741
# 13  2022-04-07T120403
# 19  2022-04-07T121025
# 30  2022-04-07T121648
# 9   2022-04-07T122312
# 20  2022-04-07T122933
# 5   2022-04-07T123554
# 38  2022-04-07T124216
# 27  2022-04-07T124838
# 39  2022-04-07T125501
# 21  2022-04-07T130125
# 31  2022-04-07T130745
# 8   2022-04-07T131407
# 14  2022-04-07T132029
# 33  2022-04-07T132652
# 18  2022-04-07T133318
# 41  2022-04-07T133941
# 46  2022-04-07T134603
# 15  2022-04-07T135227
# 23  2022-04-07T135850
# 28  2022-04-07T140517
# 12  2022-04-07T141142
# 25  2022-04-07T141813
# 1   2022-04-07T142436
# 6   2022-04-07T143059
# 22  2022-04-07T143730
# 3   2022-04-07T144353
# 11  2022-04-07T145016
# 16  2022-04-07T145641
# 29  2022-04-07T150304
# 10  2022-04-07T150925
# 35  2022-04-07T151546
# 34  2022-04-07T152209

# %% [markdown]
# Next step is to cross join this with the camera.
# All cameras should have entries for all time.

# %%
base_df = all_time.merge(cam_all, how = "cross") # change to cam_all

# %%
base_df
# Out:
#          call_timestamp  cam_id non_rainfall_station_id rainfall_station_id  \
# 0     2022-04-07T110012    1001                    S108                S119
# 1     2022-04-07T110012    1001                    S108                S119
# 2     2022-04-07T110012    1002                    S108                S215
# 3     2022-04-07T110012    1002                    S108                S215
# 4     2022-04-07T110012    1003                    S108                S123
# ...                 ...     ...                     ...                 ...
# 8766  2022-04-07T103335    9704                     S44                 S40
# 8767  2022-04-07T103335    9705                     S44                S104
# 8768  2022-04-07T103335    9705                     S44                S104
# 8769  2022-04-07T103335    9706                     S44                 S40
# 8770  2022-04-07T103335    9706                     S44                 S40
#
#      2hr_forecast_area  compass  direction
# 0              Kallang    south          1
# 1              Kallang    south          2
# 2              Geylang     east          1
# 3              Geylang     east          2
# 4              Kallang  central          1
# ...                ...      ...        ...
# 8766            Mandai    north          2
# 8767            Mandai    north          1
# 8768            Mandai    north          2
# 8769            Mandai    north          1
# 8770            Mandai    north          2
#
# [8771 rows x 7 columns]

# %%
df = base_df.merge(rainfall_realtime, on = ["call_timestamp", "rainfall_station_id"], how = "left")

# %%
len(df) == len(base_df)
# Out:
# True

# %%
df2 = df.merge(non_rainfall_realtime, on = ["call_timestamp", "non_rainfall_station_id"], how = "left")

# %%
len(df2) == len(base_df)
# Out:
# True

# %%
df3 = df2.merge(forecast_2h, on = ["call_timestamp", "2hr_forecast_area"], how = "left")

# %%
len(df3) == len(base_df)
# Out:
# True

# %%
df4 = df3.merge(forecast_4d, on = ["call_timestamp"])

# %%
len(df4) == len(base_df)
# Out:
# True

# %%
df5 = df4.merge(forecast_24h, on = ["call_timestamp", "compass"])

# %%
len(df5) == len(base_df)
# Out:
# True

# %%
df6 = df5.merge(bing_data, on = ["call_timestamp", "cam_id", "direction"])

# %%
len(df6) == len(base_df)
# Out:
# True
